# %%
#download the numpy through cmd 
# command : pip install numpy
# the import it

# %%
import numpy as np

# %%
array=np.arange(8)

# %%
array
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
array.shape
#as  we see the (1,8)and (8,) same
# Out:
# (8,)

# %%
array.reshape(2,4)
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %% [markdown]
# #by the list and tuples to make the numpy array

# %%
lis=np.array([0,1,2,3,4,5,6,7])#creating array

# %%
lis
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
lis.reshape(2,4)#it reshape the  original shape to 2*4 matrix shape
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %% [markdown]
# #as we show the list method and the numpy method is same

# %%
lis.ravel()#ravel make the shape to the original
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# #Diving into Acessing the value from the numpy array

# %%
arr=np.arange(10,50,5)# (start_value,end_value,step)

# aranging the number from 10 to 49 with the step of 5

# %%
arr
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45])

# %% [markdown]
# #Creating the identity matrix using eye method

# %%
ar=np.eye(3)#3 means 3*3matrix

# %%
ar
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# #Using full method to fill same value to the dedicated shape matrix

# %%
ar_full=np.full((4,5),fill_value=7)

# %%
ar_full
# Out:
# array([[7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7]])

# %% [markdown]
# #Creating linspace between 0 to 100 having 8 digits

# %%
ar_lin=np.linspace(0,100,8)

# %%
ar_lin
# Out:
# array([  0.        ,  14.28571429,  28.57142857,  42.85714286,
#         57.14285714,  71.42857143,  85.71428571, 100.        ])
